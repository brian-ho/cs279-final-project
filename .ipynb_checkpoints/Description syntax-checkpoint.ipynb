# %%
# -*- coding: utf-8 -*-
import pandas as pd
from textblob import TextBlob
import nltk
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

#nltk.download()

# %%
data_ = pd.read_csv('data/find2.csv')
data_a = pd.read_csv('data/find2a.csv')
data_b = pd.read_csv('data/find2b.csv')

# %%
data_['exp'] = 'fiveMT'
data_a['exp'] = 'tenMT'
data_b['exp'] = 'sevenMT'

# %%
all_data = pd.concat([data_, data_a, data_b], ignore_index=True)

# %%
df2 = all_data.apply(analyze_description, axis = 1)
# Out:
# (u'asdasdasdasdasdasdasdasda', u'NN')
# (u'asdasdasdasdasdasdasdasda', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'diamond', u'NN')
# (u'shaped', u'VBD')
# (u'yellow', u'JJ')
# (u'color', u'NN')
# (u'warning', u'VBG')
# (u'sign', u'NN')
# (u'board', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'deer', u'NN')
# (u'crossing', u'VBG')
# (u'sign', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'diamond', u'NN')
# (u'shaped', u'VBD')
# (u'yellow', u'JJ')
# (u'warning', u'NN')
# (u'sign', u'NN')
# (u'board', u'NN')
# (u'It', u'PRP')
# (u'indicates', u'VBZ')
# (u'deer', u'JJ')
# (u'crossing', u'VBG')
# (u'area', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'Really', u'RB')
# (u'good', u'JJ')
# (u'to', u'TO')
# (u'work', u'VB')
# (u'with', u'IN')
# (u'it', u'PRP')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'hot', u'JJ')
# (u'dog', u'NN')
# (u'stand', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'triangular', u'JJ')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'VBD')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'hot', u'JJ')
# (u'dog', u'NN')
# (u'stand', u'NN')
# (u'and', u'CC')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'find', u'VB')
# (u'a', u'DT')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'with', u'IN')
# (u'rope', u'NN')
# (u'around', u'IN')
# (u'it', u'PRP')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'road', u'NN')
# (u'sign', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'At', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'aSasASasASasASasASasAa', u'NN')
# (u'at', u'IN')
# (u'improves', u'NNS')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'above', u'JJ')
# (u'description', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'blue', u'NN')
# (u'box', u'NN')
# (u'above', u'IN')
# (u'so', u'RB')
# (u'that', u'IN')
# (u'other', u'JJ')
# (u'people', u'NNS')
# (u'can', u'MD')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'object', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'dark', u'NN')
# (u'colored', u'VBN')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'beside', u'VB')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'ption', u'NN')
# (u'that', u'WDT')
# (u'improves', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'above', u'JJ')
# (u'description', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'blue', u'NN')
# (u'box', u'NN')
# (u'above', u'IN')
# (u'so', u'RB')
# (u'that', u'IN')
# (u'other', u'JJ')
# (u'people', u'NNS')
# (u'can', u'MD')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'object', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'nearest', u'JJS')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'side', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'animal', u'NN')
# (u'crossing', u'VBG')
# (u'road', u'NN')
# (u'sign', u'NN')
# (u'At', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'find', u'VB')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'large', u'JJ')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'wearing', u'VBG')
# (u'a', u'DT')
# (u'christmas', u'NN')
# (u'hat', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'food', u'NN')
# (u'cart', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'red', u'JJ')
# (u'and', u'CC')
# (u'yellow', u'JJ')
# (u'umbrella', u'NN')
# (u'The', u'DT')
# (u'brown', u'JJ')
# (u'tarap', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'food', u'NN')
# (u'cart', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'red', u'JJ')
# (u'and', u'CC')
# (u'yellow', u'JJ')
# (u'umbrella', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'an', u'DT')
# (u'indicator', u'NN')
# (u'line', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'covering', u'VBG')
# (u'something', u'NN')
# (u'box', u'NN')
# (u'shaped', u'VBD')
# (u'find', u'VB')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'covering', u'VBG')
# (u'a', u'DT')
# (u'stall', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'with', u'IN')
# (u'rope', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'approximately', u'RB')
# (u'halfway', u'JJ')
# (u'back', u'RB')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'space', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'image', u'NN')
# (u'Vast', u'JJ')
# (u'view', u'NN')
# (u'with', u'IN')
# (u'visible', u'JJ')
# (u'mountains', u'NNS')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'distance', u'NN')
# (u'giving', u'VBG')
# (u'direction', u'NN')
# (u'for', u'IN')
# (u'the', u'DT')
# (u'route', u'NN')
# (u'Vast', u'NNP')
# (u'visible', u'JJ')
# (u'distance', u'NN')
# (u'with', u'IN')
# (u'mountainous', u'JJ')
# (u'view', u'NN')
# (u'caution', u'NN')
# (u'animals', u'NNS')
# (u'are', u'VBP')
# (u'passed', u'VBN')
# (u'from', u'IN')
# (u'here', u'RB')
# (u'so', u'RB')
# (u'drive', u'JJ')
# (u'slowly', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'and', u'CC')
# (u'tree', u'VB')
# (u'are', u'VBP')
# (u'down', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'starting', u'VBG')
# (u'location', u'NN')
# (u'They', u'PRP')
# (u'are', u'VBP')
# (u'both', u'DT')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'is', u'VBZ')
# (u'approximately', u'RB')
# (u'2-3', u'JJ')
# (u'feet', u'NNS')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'kindly', u'RB')
# (u'use', u'NN')
# (u'to', u'TO')
# (u'throw', u'VB')
# (u'your', u'PRP$')
# (u'waste', u'NN')
# (u'trash', u'NN')
# (u'is', u'VBZ')
# (u'by', u'IN')
# (u'street', u'NN')
# (u'on', u'IN')
# (u'top', u'NN')
# (u'of', u'IN')
# (u'grey', u'JJ')
# (u'cement', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'and', u'CC')
# (u'tree', u'VB')
# (u'are', u'VBP')
# (u'down', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'starting', u'VBG')
# (u'location', u'NN')
# (u'They', u'PRP')
# (u'are', u'VBP')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'is', u'VBZ')
# (u'approximately', u'RB')
# (u'2-3', u'JJ')
# (u'feet', u'NNS')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'asdasdasdasdasdasdasdasdasdasdasdasd', u'NN')
# (u'Good', u'JJ')
# (u'to', u'TO')
# (u'work', u'VB')
# (u'and', u'CC')
# (u'no', u'DT')
# (u'improvements', u'NNS')
# (u'are', u'VBP')
# (u'required', u'VBN')
# (u'improve', u'VB')
# (u'the', u'DT')
# (u'clarity', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'map', u'NN')
# (u'Trash', u'NN')
# (u'can', u'MD')
# (u'and', u'CC')
# (u'tree', u'VB')
# (u'are', u'VBP')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'triangular', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'an', u'DT')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'Yellow', u'NNP')
# (u'Sign', u'NNP')
# (u'with', u'IN')
# (u'an', u'DT')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'animal', u'JJ')
# (u'depiction', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'food', u'NN')
# (u'cart', u'NN')
# (u'covered', u'VBN')
# (u'by', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'It', u'PRP')
# (u'will', u'MD')
# (u'be', u'VB')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'window', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'yellow', u'JJ')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'Santa', u'NNP')
# (u'hat', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'food', u'NN')
# (u'cart', u'NN')
# (u'with', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'blue/red', u'VBD')
# (u'striped', u'VBN')
# (u'umbrellas', u'NNS')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'hot-dog', u'JJ')
# (u'vendor', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'wrapped', u'VBN')
# (u'around', u'IN')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'object', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'hot', u'JJ')
# (u'dog', u'NN')
# (u'cart', u'NN')
# (u'A', u'DT')
# (u'small', u'JJ')
# (u'market', u'NN')
# (u'cart', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'is', u'VBZ')
# (u'covered', u'VBN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'with', u'IN')
# (u'rope', u'NN')
# (u'around', u'IN')
# (u'it', u'PRP')
# (u'holding', u'VBG')
# (u'it', u'PRP')
# (u'in', u'IN')
# (u'place', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'several', u'JJ')
# (u'other', u'JJ')
# (u'street', u'NN')
# (u'vendors', u'NNS')
# (u'near', u'IN')
# (u'it', u'PRP')
# (u'Brown', u'NNP')
# (u'tarp', u'VBD')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'food', u'NN')
# (u'vendor', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'Sign', u'NNP')
# (u'pole', u'NN')
# (u'has', u'VBZ')
# (u'white', u'JJ')
# (u'wrapped', u'VBN')
# (u'around', u'IN')
# (u'it', u'PRP')
# (u'YELLOW', u'NNP')
# (u'ROAD', u'NNP')
# (u'SIGN', u'NNP')
# (u'WITH', u'NNP')
# (u'A', u'NNP')
# (u'ANIMAL', u'NNP')
# (u'IMAGE', u'NNP')
# (u'ON', u'NNP')
# (u'IT', u'NNP')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'road', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'VBD')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'hotdog', u'VB')
# (u'vendor', u'NN')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'tree', u'VB')
# (u'in', u'IN')
# (u'background', u'NN')
# (u'the', u'DT')
# (u'location', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'object', u'NN')
# (u'Trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'and', u'CC')
# (u'not', u'RB')
# (u'near', u'IN')
# (u'a', u'DT')
# (u'light', u'JJ')
# (u'post', u'NN')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'A', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'covering', u'VBG')
# (u'an', u'DT')
# (u'object', u'NN')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'that', u'WDT')
# (u'right', u'RB')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'animal', u'JJ')
# (u'crossing', u'VBG')
# (u'sign', u'NN')
# (u'The', u'DT')
# (u'second', u'JJ')
# (u'sentence', u'NN')
# (u'should', u'MD')
# (u'be', u'VB')
# (u'You', u'PRP')
# (u'may', u'MD')
# (u'need', u'VB')
# (u'to', u'TO')
# (u'zoom', u'VB')
# (u'in', u'IN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sign', u'NN')
# (u'to', u'TO')
# (u'ensure', u'VB')
# (u'you', u'PRP')
# (u"'ve", u'VBP')
# (u'found', u'VBN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'object', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'animal', u'JJ')
# (u'depiction', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'off', u'IN')
# (u'into', u'IN')
# (u'the', u'DT')
# (u'distance', u'NN')
# (u'Click', u'NNP')
# (u'here', u'RB')
# (u'when', u'WRB')
# (u'complete', u'JJ')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'hotdog', u'NN')
# (u'stand', u'VBP')
# (u'if', u'IN')
# (u'you', u'PRP')
# (u'are', u'VBP')
# (u'facing', u'VBG')
# (u'the', u'DT')
# (u'hotdog', u'NN')
# (u'stand', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'trashcan', u'JJ')
# (u'between', u'IN')
# (u'a', u'DT')
# (u'driveway', u'NN')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'Click', u'NNP')
# (u'here', u'RB')
# (u'when', u'WRB')
# (u'finished', u'VBN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'covering', u'VBG')
# (u'large', u'JJ')
# (u'object', u'JJ')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'hotdog', u'VB')
# (u'vendor', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'warning', u'NN')
# (u'of', u'IN')
# (u'animals', u'NNS')
# (u'crossing', u'VBG')
# (u'A', u'DT')
# (u'trashcan', u'JJ')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'distance', u'NN')
# (u'With', u'IN')
# (u'two', u'CD')
# (u'cars', u'NNS')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'just', u'RB')
# (u'beyond', u'IN')
# (u'it', u'PRP')
# (u'The', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'an', u'DT')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'long', u'JJ')
# (u'straight', u'JJ')
# (u'road', u'NN')
# (u'with', u'IN')
# (u'rising', u'VBG')
# (u'hills', u'NNS')
# (u'off', u'IN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'distance', u'NN')
# (u'No', u'DT')
# (u'buildings', u'NNS')
# (u'can', u'MD')
# (u'be', u'VB')
# (u'seen', u'VBN')
# (u'Look', u'NNP')
# (u'directly', u'RB')
# (u'behind', u'IN')
# (u'you', u'PRP')
# (u'and', u'CC')
# (u'across', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'for', u'IN')
# (u'a', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'animal', u'JJ')
# (u'depiction', u'NN')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'under', u'IN')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'where', u'WRB')
# (u'the', u'DT')
# (u'curve', u'NN')
# (u'begins', u'VBZ')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'pickup', u'NN')
# (u'truck', u'NN')
# (u'Tarp', u'NNP')
# (u'covering', u'VBG')
# (u'vendor', u'NN')
# (u'with', u'IN')
# (u'ropes', u'NNS')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'covering', u'VBG')
# (u'something', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'hotdog', u'NN')
# (u'vendor', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'covering', u'VBG')
# (u'something', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'man', u'NN')
# (u'sitting', u'VBG')
# (u'on', u'IN')
# (u'crate', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'food', u'NN')
# (u'cart', u'NN')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'closest', u'JJS')
# (u'driveway', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'adjacent', u'JJ')
# (u'to', u'TO')
# (u'parked', u'VB')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'is', u'VBZ')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'edge', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'driveway', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'black', u'JJ')
# (u'and', u'CC')
# (u'small', u'JJ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'The', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'underneath', u'NN')
# (u'the', u'DT')
# (u'blue', u'JJ')
# (u'm', u'NN')
# (u'and', u'CC')
# (u'm', u'JJ')
# (u'billboard', u'NN')
# (u'Trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'curb', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'diamond', u'NN')
# (u'shaped', u'VBD')
# (u'sign', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Please', u'VB')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'Yellow', u'NNP')
# (u'Rhombus', u'NNP')
# (u'shaped', u'VBD')
# (u'street', u'NN')
# (u'sign', u'NN')
# (u'The', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'dimond', u'JJ')
# (u'shaped', u'VBN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'prarie', u'NN')
# (u'Yellow', u'NNP')
# (u'Animal', u'NNP')
# (u'Crossing', u'NNP')
# (u'Sign', u'NNP')
# (u'Diamond-shaped', u'JJ')
# (u'sign', u'NN')
# (u'that', u'IN')
# (u'warns', u'VBZ')
# (u'of', u'IN')
# (u'animals', u'NNS')
# (u'along/crossing', u'VBG')
# (u'road', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'Diamond', u'NNP')
# (u'shaped', u'VBD')
# (u'yellow', u'JJ')
# (u'road', u'NN')
# (u'sign', u'NN')
# (u'The', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'right', u'VB')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'with', u'IN')
# (u'cars', u'NNS')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'background', u'NN')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'Ms', u'NNP')
# (u'store', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'black', u'JJ')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'Trashcan', u'JJ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'behind', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'car', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'stret', u'NN')
# (u'Trash', u'NN')
# (u'Can', u'MD')
# (u'near', u'VB')
# (u'Tree', u'NNP')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'Silver', u'NNP')
# (u'Car', u'NNP')
# (u'in', u'IN')
# (u'Driveway', u'NNP')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'and', u'CC')
# (u'the', u'DT')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'The', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'an', u'DT')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'no', u'DT')
# (u'houses', u'NNS')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'sign', u'NN')
# (u'and', u'CC')
# (u'the', u'DT')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'pretty', u'RB')
# (u'far', u'RB')
# (u'away', u'RB')
# (u'Brown', u'NNP')
# (u'Tarp', u'NNP')
# (u'on', u'IN')
# (u'street', u'NN')
# (u'near', u'IN')
# (u'Yellow', u'NNP')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'covering', u'VBG')
# (u'large', u'JJ')
# (u'object', u'NN')
# (u'behind', u'IN')
# (u'sitting', u'VBG')
# (u'man', u'NN')
# (u'on', u'IN')
# (u'left', u'JJ')
# (u'sidewalk', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'is', u'VBZ')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'basketball', u'NN')
# (u'hoop', u'NN')
# (u'in', u'IN')
# (u'it', u'PRP')
# (u"'s", u'VBZ')
# (u'driveway', u'NN')
# (u'Yellow', u'JJ')
# (u'Sign', u'NNP')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'At', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'an', u'DT')
# (u'empty', u'JJ')
# (u'driveway', u'NN')
# (u'next', u'JJ')
# (u'driveway', u'NN')
# (u'past', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'has', u'VBZ')
# (u'at', u'IN')
# (u'least', u'JJS')
# (u'three', u'CD')
# (u'vehicles', u'NNS')
# (u'in', u'IN')
# (u'it', u'PRP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'by', u'IN')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'truck', u'NN')
# (u'parked', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'yellow', u'JJ')
# (u'traffic', u'NN')
# (u'sign', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Please', u'NNP')
# (u'turn', u'VB')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'You', u'PRP')
# (u'will', u'MD')
# (u'see', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'right', u'RB')
# (u'away', u'RB')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'right', u'VB')
# (u'beside', u'VB')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'no', u'DT')
# (u'cars', u'NNS')
# (u'parked', u'VBD')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'close', u'RB')
# (u'to', u'TO')
# (u'this', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'food', u'NN')
# (u'vendor', u'NN')
# (u'with', u'IN')
# (u'two', u'CD')
# (u'multicolored', u'VBD')
# (u'umbrellas', u'NNS')
# (u'above', u'IN')
# (u'it', u'PRP')
# (u'The', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'candy', u'NN')
# (u'store', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'covering', u'VBG')
# (u'up', u'RP')
# (u'something', u'NN')
# (u'big', u'JJ')
# (u'and', u'CC')
# (u'has', u'VBZ')
# (u'a', u'DT')
# (u'rope', u'NN')
# (u'around', u'IN')
# (u'it', u'PRP')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'hotdog', u'NN')
# (u'stand', u'NN')
# (u'It', u'PRP')
# (u"'s", u'VBZ')
# (u'easy', u'JJ')
# (u'to', u'TO')
# (u'find', u'VB')
# (u'it', u'PRP')
# (u'placed', u'VBD')
# (u'just', u'RB')
# (u'left', u'VBN')
# (u'hand', u'NN')
# (u'side', u'NN')
# (u'near', u'IN')
# (u'starting', u'VBG')
# (u'point', u'NN')
# (u'only', u'RB')
# (u'On', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'highway', u'NN')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'yellow', u'NN')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'The', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'standing', u'VBG')
# (u'alone', u'RB')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'Pan', u'NNP')
# (u'right', u'NN')
# (u'to', u'TO')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'silver', u'NN')
# (u'pickup', u'JJ')
# (u'truck', u'NN')
# (u'parked', u'VBN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'then', u'RB')
# (u'look', u'VB')
# (u'just', u'RB')
# (u'behind', u'IN')
# (u'it', u'PRP')
# (u'for', u'IN')
# (u'the', u'DT')
# (u'black', u'JJ')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'dark', u'NN')
# (u'grey', u'NN')
# (u'SUV', u'NNP')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'small', u'JJ')
# (u'yellow', u'JJ')
# (u'traffic', u'NN')
# (u'sign', u'NN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'I', u'PRP')
# (u'was', u'VBD')
# (u'expecting', u'VBG')
# (u'it', u'PRP')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'closer', u'JJR')
# (u'Say', u'NNP')
# (u'that', u'IN')
# (u'it', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'bit', u'RB')
# (u'down', u'RP')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Square', u'NNP')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'beginning', u'NN')
# (u'view', u'NN')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'closest', u'JJS')
# (u'driveway', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'adjacent', u'JJ')
# (u'to', u'TO')
# (u'parked', u'VB')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'and', u'CC')
# (u'black', u'JJ')
# (u'SUV', u'NNP')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'across', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'near', u'IN')
# (u'the', u'DT')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'in', u'IN')
# (u'between', u'IN')
# (u'the', u'DT')
# (u'blue', u'NN')
# (u'car', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'and', u'CC')
# (u'the', u'DT')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'parked', u'VBN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'It', u'PRP')
# (u'would', u'MD')
# (u'be', u'VB')
# (u'better', u'JJR')
# (u'to', u'TO')
# (u'say', u'VB')
# (u'how', u'WRB')
# (u'far', u'RB')
# (u'left', u'VBD')
# (u'i', u'JJ')
# (u'need', u'VBP')
# (u'to', u'TO')
# (u'turn', u'VB')
# (u'like', u'IN')
# (u'160', u'CD')
# (u'degrees', u'NNS')
# (u'or', u'CC')
# (u'something', u'NN')
# (u'like', u'IN')
# (u'that', u'DT')
# (u'Locate', u'VB')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'beside', u'IN')
# (u'the', u'DT')
# (u'Blue/Yellow', u'NNP')
# (u'and', u'CC')
# (u'Red/Yellow', u'NNP')
# (u'umbrellas', u'NNS')
# (u'Turn', u'NNP')
# (u'to', u'TO')
# (u'your', u'PRP$')
# (u'left', u'NNS')
# (u'and', u'CC')
# (u'look', u'VB')
# (u'for', u'IN')
# (u'a', u'DT')
# (u'truck', u'NN')
# (u'and', u'CC')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'black', u'JJ')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'near', u'VB')
# (u'it', u'PRP')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'and', u'CC')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'driveway', u'NN')
# (u'Black', u'NNP')
# (u'roller', u'NN')
# (u'trash', u'NN')
# (u'cab', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'walk', u'NN')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'SUV', u'NNP')
# (u'parked', u'VBD')
# (u'in', u'IN')
# (u'it', u'PRP')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'silver', u'NN')
# (u'trucked', u'VBN')
# (u'parked', u'VBN')
# (u'out', u'RP')
# (u'front', u'NN')
# (u'You', u'PRP')
# (u'may', u'MD')
# (u'have', u'VB')
# (u'to', u'TO')
# (u'move', u'VB')
# (u'the', u'DT')
# (u'camera', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'opposite', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'original', u'JJ')
# (u'view', u'NN')
# (u'Move', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'then', u'RB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'hotdog', u'JJ')
# (u'cart', u'NN')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'picture', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'yellow', u'NNP')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'black', u'JJ')
# (u'SUV', u'NNP')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'medium', u'NN')
# (u'sized', u'VBN')
# (u'black', u'JJ')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'outside', u'VB')
# (u'a', u'DT')
# (u'house', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'closet', u'NN')
# (u'driveway', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'infront', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'two', u'CD')
# (u'stories', u'NNS')
# (u'red', u'JJ')
# (u'house', u'NN')
# (u'adjacent', u'JJ')
# (u'to', u'TO')
# (u'parked', u'VB')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'The', u'DT')
# (u'black', u'JJ')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'drive', u'JJ')
# (u'way', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'where', u'WRB')
# (u'there', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'silver', u'NN')
# (u'pick', u'NN')
# (u'up', u'RP')
# (u'truck', u'NN')
# (u'parked', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'it', u'PRP')
# (u'Object', u'NN')
# (u'covered', u'VBD')
# (u'with', u'IN')
# (u'Brown', u'NNP')
# (u'Tarp', u'NNP')
# (u'on', u'IN')
# (u'sidewalk', u'NN')
# (u'under', u'IN')
# (u'red', u'JJ')
# (u'and', u'CC')
# (u'yellow', u'JJ')
# (u'umbrella', u'NN')
# (u'The', u'DT')
# (u'object', u'NN')
# (u'wrapped', u'VBD')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'directly', u'RB')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'yellow', u'NNP')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'character', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'man', u'NN')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'blue', u'NN')
# (u'jacket', u'NN')
# (u'sitting', u'VBG')
# (u'near', u'JJ')
# (u'it', u'PRP')
# (u'as', u'RB')
# (u'well', u'RB')
# (u'as', u'IN')
# (u'some', u'DT')
# (u'umbrellas', u'NNS')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'The', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'object', u'NN')
# (u'can', u'MD')
# (u'be', u'VB')
# (u'found', u'VBN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'curb', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'Sabrett', u'NNP')
# (u'hot', u'JJ')
# (u'dog', u'NN')
# (u'stand', u'NN')
# (u'and', u'CC')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'store', u'NN')
# (u'that', u'WDT')
# (u'has', u'VBZ')
# (u'a', u'DT')
# (u'window', u'JJ')
# (u'display', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'giant', u'JJ')
# (u'yellow', u'JJ')
# (u'Peanut', u'NNP')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'A', u'DT')
# (u'large', u'JJ')
# (u'item', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'about', u'IN')
# (u'the', u'DT')
# (u'size', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'hot', u'JJ')
# (u'dog', u'NN')
# (u'cart', u'NN')
# (u'is', u'VBZ')
# (u'covered', u'VBN')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'a', u'DT')
# (u'reflection', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'giant', u'JJ')
# (u'yellow', u'JJ')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'can', u'MD')
# (u'be', u'VB')
# (u'seen', u'VBN')
# (u'behind', u'IN')
# (u'the', u'DT')
# (u'object', u'NN')
# (u'You', u'PRP')
# (u'need', u'VBP')
# (u'to', u'TO')
# (u'turn', u'VB')
# (u'around', u'RP')
# (u'but', u'CC')
# (u'it', u'PRP')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'The', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'straight', u'JJ')
# (u'ahead', u'RB')
# (u'The', u'DT')
# (u'Yellow', u'NNP')
# (u'sign', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'Highway', u'NNP')
# (u'turn', u'VB')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'around', u'IN')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'Black', u'NNP')
# (u'SUV', u'NNP')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'is', u'VBZ')
# (u'near', u'IN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'the', u'DT')
# (u'description', u'NN')
# (u'is', u'VBZ')
# (u'very', u'RB')
# (u'clearly', u'RB')
# (u'to', u'TO')
# (u'get', u'VB')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'yellow', u'JJ')
# (u'diamond', u'NN')
# (u'shaped', u'VBD')
# (u'street', u'NN')
# (u'sign', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'It', u'PRP')
# (u"'s", u'VBZ')
# (u'immediately', u'RB')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'of', u'IN')
# (u'our', u'PRP$')
# (u'view', u'NN')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NNP')
# (u'parked', u'VBD')
# (u'in', u'IN')
# (u'teh', u'JJ')
# (u'drivway', u'NN')
# (u'It', u'PRP')
# (u"'s", u'VBZ')
# (u'a', u'DT')
# (u'little', u'JJ')
# (u'off', u'RP')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'distance', u'NN')
# (u'Turn', u'NNP')
# (u'slightly', u'RB')
# (u'left', u'VBD')
# (u'to', u'TO')
# (u'see', u'VB')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'Outdoor', u'NNP')
# (u'garbage', u'NN')
# (u'can', u'MD')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'white', u'JJ')
# (u'home', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'black', u'JJ')
# (u'SUV', u'NNP')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'parked', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'basketball', u'NN')
# (u'goal', u'NN')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'parked', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'home', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'WITHOUT', u'IN')
# (u'MOVING', u'NNP')
# (u'look', u'VBP')
# (u'around', u'IN')
# (u'the', u'DT')
# (u'google', u'JJ')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'image', u'NN')
# (u'zoom', u'NN')
# (u'if', u'IN')
# (u'necessary', u'JJ')
# (u'until', u'IN')
# (u'you', u'PRP')
# (u'locate', u'VBP')
# (u'the', u'DT')
# (u'following', u'JJ')
# (u'object', u'NN')
# (u'Black', u'NNP')
# (u'roller', u'NN')
# (u'trash', u'NN')
# (u'cab', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'walk', u'NN')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'SUV', u'NNP')
# (u'parked', u'VBD')
# (u'in', u'IN')
# (u'it', u'PRP')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'silver', u'NN')
# (u'trucked', u'VBN')
# (u'parked', u'VBN')
# (u'out', u'RP')
# (u'front', u'NN')
# (u'It', u'PRP')
# (u"'s", u'VBZ')
# (u'more', u'JJR')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'sign', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Yellow', u'JJ')
# (u'sign', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'warning', u'NN')
# (u'of', u'IN')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'road', u'NN')
# (u'I', u'PRP')
# (u'think', u'VBP')
# (u'I', u'PRP')
# (u'had', u'VBD')
# (u'to', u'TO')
# (u'turn', u'VB')
# (u'right', u'JJ')
# (u'instead', u'RB')
# (u'of', u'IN')
# (u'left', u'NN')
# (u'Yellow', u'IN')
# (u'triangular', u'JJ')
# (u'street', u'NN')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'shown', u'VBN')
# (u'when', u'WRB')
# (u'the', u'DT')
# (u'Google', u'NNP')
# (u'viewer', u'NN')
# (u'is', u'VBZ')
# (u'panned', u'VBN')
# (u'towards', u'IN')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'The', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'is', u'VBZ')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'brown', u'JJ')
# (u'doors', u'NNS')
# (u'black', u'JJ')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'corner', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'behind', u'IN')
# (u'the', u'DT')
# (u'SUV', u'NNP')
# (u'Black', u'NNP')
# (u'trashcan', u'JJ')
# (u'near', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'The', u'DT')
# (u'line', u'NN')
# (u'is', u'VBZ')
# (u'faint', u'JJ')
# (u'and', u'CC')
# (u'need', u'MD')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'thickened', u'VBN')
# (u'located', u'VBN')
# (u'ont', u'IN')
# (u'the', u'DT')
# (u'border', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'grass', u'NN')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'person', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'green', u'JJ')
# (u'coat', u'NN')
# (u'is', u'VBZ')
# (u'walking', u'VBG')
# (u'behind', u'IN')
# (u'it', u'PRP')
# (u'roller', u'NN')
# (u'trash', u'NN')
# (u'cab', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'walk', u'NN')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'SUV', u'NNP')
# (u'parked', u'VBD')
# (u'in', u'IN')
# (u'it', u'PRP')
# (u'It', u'PRP')
# (u"'s", u'VBZ')
# (u'the', u'DT')
# (u'opposite', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'On', u'IN')
# (u'a', u'DT')
# (u'road', u'NN')
# (u'a', u'DT')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'is', u'VBZ')
# (u'parked', u'VBN')
# (u'and', u'CC')
# (u'right', u'RB')
# (u'in', u'IN')
# (u'its', u'PRP$')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'truck', u'NN')
# (u'a', u'DT')
# (u'black', u'JJ')
# (u'trash', u'NN')
# (u'bin', u'NN')
# (u'has', u'VBZ')
# (u'been', u'VBN')
# (u'put', u'VBN')
# (u'there', u'RB')
# (u'which', u'WDT')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'You', u'PRP')
# (u'can', u'MD')
# (u'also', u'RB')
# (u'see', u'VB')
# (u'the', u'DT')
# (u'another', u'DT')
# (u'vehicle', u'NN')
# (u'of', u'IN')
# (u'white', u'JJ')
# (u'color', u'NN')
# (u'is', u'VBZ')
# (u'standing', u'VBG')
# (u'in', u'IN')
# (u'behind', u'NN')
# (u'of', u'IN')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'few', u'JJ')
# (u'distance', u'NN')
# (u'back', u'RB')
# (u'And', u'CC')
# (u'Straight', u'NNP')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'bin', u'NN')
# (u'you', u'PRP')
# (u'can', u'MD')
# (u'see', u'VB')
# (u'that', u'IN')
# (u'an', u'DT')
# (u'SUV', u'NNP')
# (u'is', u'VBZ')
# (u'also', u'RB')
# (u'parked', u'VBN')
# (u'right', u'RB')
# (u'there', u'RB')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'the', u'DT')
# (u'explanation', u'NN')
# (u'is', u'VBZ')
# (u'clearly', u'RB')
# (u'to', u'TO')
# (u'get', u'VB')
# (u'that', u'IN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'an', u'DT')
# (u'big', u'JJ')
# (u'object', u'NN')
# (u'covered', u'VBD')
# (u'with', u'IN')
# (u'brown', u'JJ')
# (u'color', u'NN')
# (u'sheet', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'In', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'it', u'PRP')
# (u'a', u'DT')
# (u'monster', u'RBR')
# (u'billboard', u'NN')
# (u'of', u'IN')
# (u'yellow', u'JJ')
# (u'color', u'NN')
# (u'can', u'MD')
# (u'be', u'VB')
# (u'seen', u'VBN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'huge', u'JJ')
# (u'sign', u'NN')
# (u'of', u'IN')
# (u'M', u'NNP')
# (u'written', u'VBN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'Few', u'JJ')
# (u'steps', u'NNS')
# (u'ahead', u'RB')
# (u'there', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'X-mas', u'JJ')
# (u'tree', u'NN')
# (u'with', u'IN')
# (u'decoration', u'NN')
# (u'can', u'MD')
# (u'be', u'VB')
# (u'seen', u'VBN')
# (u'Large', u'JJ')
# (u'object', u'NN')
# (u'wrapped', u'VBD')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'big', u'JJ')
# (u'brown', u'NN')
# (u'tarp', u'NN')
# (u'On', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'M', u'NNP')
# (u'and', u'CC')
# (u'M', u'NNP')
# (u'photo', u'NN')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'store', u'NN')
# (u'A', u'DT')
# (u'brown', u'JJ')
# (u'plastic', u'NN')
# (u'tarp', u'NN')
# (u'near', u'IN')
# (u'the', u'DT')
# (u'yellow', u'NN')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'yellow', u'JJ')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'behind', u'IN')
# (u'it', u'PRP')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'drive', u'NN')
# (u'way', u'NN')
# (u'where', u'WRB')
# (u'a', u'DT')
# (u'black', u'JJ')
# (u'SUV', u'NNP')
# (u'is', u'VBZ')
# (u'parked', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'basketball', u'NN')
# (u'hoop', u'NN')
# (u'Yellow', u'JJ')
# (u'sign', u'NN')
# (u'notifying', u'NN')
# (u'of', u'IN')
# (u'animal', u'NN')
# (u'crossing', u'NN')
# (u'will', u'MD')
# (u'be', u'VB')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'screen.You', u'NN')
# (u'must', u'MD')
# (u'use', u'VB')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'yellow', u'JJ')
# (u'line', u'NN')
# (u'the', u'DT')
# (u'shows', u'NNS')
# (u'the', u'DT')
# (u'center', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'yellow', u'JJ')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'directly', u'RB')
# (u'behind', u'IN')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'covering', u'VBG')
# (u'a', u'DT')
# (u'cart', u'NN')
# (u'protecting', u'VBG')
# (u'it', u'PRP')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'rain', u'NN')
# (u'Large', u'JJ')
# (u'object', u'NN')
# (u'wrapped', u'VBD')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'vendor', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'under', u'IN')
# (u'yellow', u'NN')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'The', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'hot', u'JJ')
# (u'dog', u'NN')
# (u'stand', u'NN')
# (u'and', u'CC')
# (u'the', u'DT')
# (u'man', u'NN')
# (u'sitting', u'VBG')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'crate', u'NN')
# (u'`1234234234234234242342342', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'image', u'NN')
# (u'The', u'DT')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'a', u'DT')
# (u'brick', u'NN')
# (u'patio', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'tan', u'NN')
# (u'roof', u'NN')
# (u'that', u'WDT')
# (u'has', u'VBZ')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NNP')
# (u'parked', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'food', u'NN')
# (u'kart', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'The', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'behind', u'IN')
# (u'you', u'PRP')
# (u'so', u'RB')
# (u'turn', u'VB')
# (u'around', u'RP')
# (u'The', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'to', u'TO')
# (u'your', u'PRP$')
# (u'right', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'located', u'VBN')
# (u'directly', u'RB')
# (u'behind', u'IN')
# (u'you', u'PRP')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'image', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'bench', u'NN')
# (u'behind', u'IN')
# (u'you', u'PRP')
# (u'Turn', u'NNP')
# (u'around', u'RP')
# (u'and', u'CC')
# (u'look', u'VB')
# (u'towards', u'IN')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'The', u'DT')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'located', u'VBN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'front', u'JJ')
# (u'patio', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'single', u'JJ')
# (u'story', u'NN')
# (u'home', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'on', u'IN')
# (u'a', u'DT')
# (u'busy', u'JJ')
# (u'street', u'NN')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'food', u'NN')
# (u'stand', u'NN')
# (u'Look', u'NN')
# (u'for', u'IN')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'anSUV', u'NN')
# (u'parked', u'VBN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'covering', u'VBG')
# (u'an', u'DT')
# (u'object', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'located', u'VBN')
# (u'on', u'IN')
# (u'a', u'DT')
# (u'sidewalk', u'NN')
# (u'near', u'IN')
# (u'a', u'DT')
# (u'red', u'JJ')
# (u'and', u'CC')
# (u'yellow', u'JJ')
# (u'umbrella', u'NN')
# (u'Look', u'NNP')
# (u'tdown', u'JJ')
# (u'and', u'CC')
# (u'right', u'JJ')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'yellow', u'NNP')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u'guy', u'NN')
# (u'the', u'DT')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'located', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'by', u'IN')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'truck', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'no', u'DT')
# (u'bench', u'NN')
# (u'in', u'IN')
# (u'this', u'DT')
# (u'photo', u'NN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'shaped', u'VBN')
# (u'like', u'IN')
# (u'a', u'DT')
# (u'diamond', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'It', u'PRP')
# (u"'s", u'VBZ')
# (u'a', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'The', u'DT')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'road', u'NN')
# (u'Yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'A', u'DT')
# (u'row', u'NN')
# (u'of', u'IN')
# (u'umbrellas', u'JJ')
# (u'line', u'NN')
# (u'the', u'DT')
# (u'edge', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'along', u'IN')
# (u'with', u'IN')
# (u'chairs', u'NNS')
# (u'and', u'CC')
# (u'what', u'WP')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'vendor', u'JJ')
# (u'booths', u'NNS')
# (u'Midway', u'NNP')
# (u'down', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'visible', u'JJ')
# (u'and', u'CC')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'securing', u'VBG')
# (u'property', u'NN')
# (u'or', u'CC')
# (u'merchandise', u'NN')
# (u'while', u'IN')
# (u'a', u'DT')
# (u'man', u'NN')
# (u'sits', u'VBZ')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'chair', u'NN')
# (u'with', u'IN')
# (u'his', u'PRP$')
# (u'back', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'bungle', u'NN')
# (u'secured', u'VBN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'A', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'deer/llama/wild', u'JJ')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'Using', u'VBG')
# (u'the', u'DT')
# (u'google', u'NN')
# (u'map', u'NN')
# (u'Its', u'PRP$')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Turn', u'NN')
# (u'to', u'TO')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'street', u'NN')
# (u'sign', u'NN')
# (u'Its', u'PRP$')
# (u'right', u'JJ')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'food', u'NN')
# (u'vendor', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'wearing', u'VBG')
# (u'a', u'DT')
# (u'blue', u'NN')
# (u'shirt', u'NN')
# (u'it', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'small', u'JJ')
# (u'American', u'JJ')
# (u'flag', u'NN')
# (u'mailbox', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'pole', u'NN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'door', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'bench', u'NN')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'bench', u'NN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'long', u'JJ')
# (u'driveway', u'NN')
# (u'it', u'PRP')
# (u'is', u'VBZ')
# (u'also', u'RB')
# (u'under', u'IN')
# (u'the', u'DT')
# (u'windows', u'NNS')
# (u'and', u'CC')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'door', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'Yellow', u'JJ')
# (u'sign', u'NN')
# (u'is', u'VBZ')
# (u'down', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'away', u'RB')
# (u'from', u'IN')
# (u'any', u'DT')
# (u'structures', u'NNS')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'picture', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'black', u'JJ')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'The', u'DT')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'located', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'bricks', u'NNS')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'patio', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'The', u'DT')
# (u'house', u'NN')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'have', u'VB')
# (u'a', u'DT')
# (u'second', u'JJ')
# (u'story', u'NN')
# (u'or', u'CC')
# (u'attic', u'JJ')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'tan', u'JJ')
# (u'roof', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'columns', u'NNS')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'front', u'JJ')
# (u'door', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'bench', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'window', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'front', u'JJ')
# (u'door', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'tan', u'JJ')
# (u'roof', u'NN')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'short', u'JJ')
# (u'decorative', u'NN')
# (u'tree', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'front', u'JJ')
# (u'door', u'NN')
# (u'The', u'DT')
# (u'house', u'NN')
# (u'in', u'IN')
# (u'question', u'NN')
# (u'is', u'VBZ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'roofed', u'NN')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'red', u'JJ')
# (u'car', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'drive', u'NN')
# (u'Both', u'DT')
# (u'houses', u'NNS')
# (u'are', u'VBP')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'Man', u'NN')
# (u'in', u'IN')
# (u'blue', u'JJ')
# (u'jacket', u'NN')
# (u'is', u'VBZ')
# (u'sitting', u'VBG')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'street', u'VB')
# (u'on', u'IN')
# (u'sidewalk', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'food', u'NN')
# (u'cart', u'NN')
# (u'A', u'DT')
# (u'row', u'NN')
# (u'of', u'IN')
# (u'umbrellas', u'JJ')
# (u'line', u'NN')
# (u'the', u'DT')
# (u'edge', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'along', u'IN')
# (u'with', u'IN')
# (u'chairs', u'NNS')
# (u'and', u'CC')
# (u'what', u'WP')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'vendor', u'JJ')
# (u'booths', u'NNS')
# (u'Midway', u'NNP')
# (u'down', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'visible', u'JJ')
# (u'and', u'CC')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'securing', u'VBG')
# (u'property', u'NN')
# (u'or', u'CC')
# (u'merchandise', u'NN')
# (u'while', u'IN')
# (u'a', u'DT')
# (u'man', u'NN')
# (u'sits', u'VBZ')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'chair', u'NN')
# (u'with', u'IN')
# (u'his', u'PRP$')
# (u'back', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'bungle', u'NN')
# (u'secured', u'VBN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'On', u'IN')
# (u'the', u'DT')
# (u'wall', u'NN')
# (u'behind', u'IN')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'there', u'EX')
# (u"'s", u'VBZ')
# (u'a', u'DT')
# (u'picture', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'yellow', u'JJ')
# (u'M', u'NNP')
# (u'&', u'CC')
# (u'M', u'NNP')
# (u"'s", u'POS')
# (u'A', u'DT')
# (u'man', u'NN')
# (u'is', u'VBZ')
# (u'sitting', u'VBG')
# (u'on', u'IN')
# (u'a', u'DT')
# (u'chair', u'NN')
# (u'and', u'CC')
# (u'his', u'PRP$')
# (u'back', u'NN')
# (u'is', u'VBZ')
# (u'facing', u'VBG')
# (u'a', u'DT')
# (u'big', u'JJ')
# (u'brown', u'NN')
# (u'tarp', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'umbrellas', u'JJ')
# (u'right', u'RB')
# (u'behind', u'IN')
# (u'him', u'PRP')
# (u'and', u'CC')
# (u'there', u'EX')
# (u'are', u'VBP')
# (u'other', u'JJ')
# (u'people', u'NNS')
# (u'sitting', u'VBG')
# (u'in', u'IN')
# (u'chairs', u'NNS')
# (u'next', u'IN')
# (u'to', u'TO')
# (u'him', u'PRP')
# (u'On', u'IN')
# (u'the', u'DT')
# (u'left', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'a', u'DT')
# (u'vendor', u'NN')
# (u'cart', u'NN')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'man', u'NN')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'blue', u'NN')
# (u'jacket', u'NN')
# (u'sitting', u'VBG')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'of', u'IN')
# (u'an', u'DT')
# (u'object', u'NN')
# (u'perhaps', u'RB')
# (u'a', u'DT')
# (u'cart', u'NN')
# (u'or', u'CC')
# (u'merchandise', u'NN')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'wrapped', u'VBN')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'two', u'CD')
# (u'umbrellas', u'NNS')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'vendor', u'NN')
# (u'stand', u'NN')
# (u'One', u'CD')
# (u'is', u'VBZ')
# (u'blue', u'JJ')
# (u'and', u'CC')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'the', u'DT')
# (u'other', u'JJ')
# (u'in', u'IN')
# (u'red', u'JJ')
# (u'and', u'CC')
# (u'yellow', u'JJ')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'blue', u'JJ')
# (u'lettering', u'VBG')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sign', u'NN')
# (u'Behind', u'IN')
# (u'the', u'DT')
# (u'vendor', u'NN')
# (u'stand', u'NN')
# (u'there', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'building', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'm', u'NN')
# (u'&', u'CC')
# (u'm', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'window', u'NN')
# (u'The', u'DT')
# (u'house', u'NN')
# (u'is', u'VBZ')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'besides', u'IN')
# (u'the', u'DT')
# (u'housed', u'VBN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'red', u'JJ')
# (u'car', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'Sign', u'NNP')
# (u'that', u'WDT')
# (u'is', u'VBZ')
# (u'ahead', u'RB')
# (u'it', u'PRP')
# (u'is', u'VBZ')
# (u'yellow', u'JJ')
# (u'The', u'DT')
# (u'house', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'opposite', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'where', u'WRB')
# (u'you', u'PRP')
# (u'will', u'MD')
# (u'begin', u'VB')
# (u'It', u'PRP')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'ranch', u'NN')
# (u'style', u'NN')
# (u'home', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'tan', u'JJ')
# (u'roof', u'NN')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'bench', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'driveway', u'JJ')
# (u'side', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'two', u'CD')
# (u'white', u'JJ')
# (u'columns', u'NNS')
# (u'on', u'IN')
# (u'either', u'DT')
# (u'side', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'entryway', u'NN')
# (u'A', u'DT')
# (u'man', u'NN')
# (u'sitting', u'VBG')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'chair', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'underneath', u'IN')
# (u'an', u'DT')
# (u'umbrella', u'NN')
# (u'colored', u'VBD')
# (u'red', u'JJ')
# (u'and', u'CC')
# (u'yellow', u'JJ')
# (u'with', u'IN')
# (u'his', u'PRP$')
# (u'back', u'NN')
# (u'facing', u'VBG')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'brown', u'JJ')
# (u'bundle', u'NN')
# (u'Just', u'RB')
# (u'rotate', u'VB')
# (u'the', u'DT')
# (u'view', u'NN')
# (u'and', u'CC')
# (u'you', u'PRP')
# (u'can', u'MD')
# (u'easily', u'RB')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'object', u'NN')
# (u'Scan', u'JJ')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'to', u'TO')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'snack', u'JJ')
# (u'stand', u'NN')
# (u'with', u'IN')
# (u'two', u'CD')
# (u'umbrellas', u'NNS')
# (u'on', u'IN')
# (u'top', u'NN')
# (u'with', u'IN')
# (u'an', u'DT')
# (u'object', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'over', u'IN')
# (u'it', u'PRP')
# (u'to', u'TO')
# (u'it', u'PRP')
# (u"'s", u'VBZ')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'man', u'NN')
# (u'sitting', u'VBG')
# (u'with', u'IN')
# (u'his', u'PRP$')
# (u'back', u'NN')
# (u'facing', u'VBG')
# (u'the', u'DT')
# (u'tarp', u'NN')
# (u'This', u'DT')
# (u'is', u'VBZ')
# (u'along', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'curb', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'building', u'NN')
# (u'with', u'IN')
# (u'all', u'PDT')
# (u'the', u'DT')
# (u'windows', u'NNS')
# (u'Turn', u'NNP')
# (u'in', u'IN')
# (u'360', u'CD')
# (u'degrees', u'NNS')
# (u'to', u'TO')
# (u'find', u'VB')
# (u'objects', u'NNS')
# (u'Behind', u'IN')
# (u'the', u'DT')
# (u'man', u'NN')
# (u'sitting', u'VBG')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'brown', u'NN')
# (u'tarp', u'NN')
# (u'behind', u'IN')
# (u'him', u'PRP')
# (u'there', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'shop', u'NN')
# (u'front', u'NN')
# (u'that', u'WDT')
# (u'has', u'VBZ')
# (u'an', u'DT')
# (u'm', u'NN')
# (u'&', u'CC')
# (u'm', u'JJ')
# (u'mural', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'window', u'NN')
# (u'Please', u'NNP')
# (u'write', u'VB')
# (u'a', u'DT')
# (u'description', u'NN')
# (u'that', u'WDT')
# (u'improves', u'VBZ')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'above', u'JJ')
# (u'description', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'blue', u'NN')
# (u'box', u'NN')
# (u'above', u'IN')
# (u'so', u'RB')
# (u'that', u'IN')
# (u'other', u'JJ')
# (u'people', u'NNS')
# (u'can', u'MD')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'object', u'NN')
# (u'The', u'DT')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'located', u'VBN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'right', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'front', u'JJ')
# (u'door', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'wood', u'NN')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'columns', u'NN')
# (u'supporting', u'VBG')
# (u'the', u'DT')
# (u'awning', u'NN')
# (u'over', u'IN')
# (u'the', u'DT')
# (u'entry', u'NN')
# (u'way', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'near', u'IN')
# (u'the', u'DT')
# (u'bench', u'NN')
# (u'and', u'CC')
# (u'there', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'small', u'JJ')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'opposite', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'entry', u'NN')
# (u'way', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'small', u'JJ')
# (u'tree', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'window', u'NN')
# (u'on', u'IN')
# (u'your', u'PRP$')
# (u'left', u'JJ')
# (u'side', u'NN')

# %%
df2.to_csv('all_descriptions_syntax.csv')

# %%
descrip_ = pd.read_csv('data/descriptions2.csv')
descrip_a = pd.read_csv('data/descriptions2a.csv')
descrip_b = pd.read_csv('data/descriptions2b.csv')

# %%
descrip_['exp'] = 'fiveMT'
descrip_a['exp'] = 'tenMT'
descrip_b['exp'] = 'sevenMT'

# %%
def analyze_description(df):
    adj = 0
    prep = 0
    noun = 0
    text = unicode(df.updated, "utf-8")
    pos = TextBlob(text).tags
    for part in pos:
        print part
        if part[1] in ['IN']:
            prep += 1
        if part[1] in ['JJ', 'JJR', 'JJS']:
            adj += 1
        if part[1] in ['NN', 'NNP','NNPS','NNS']:
            noun += 1
    
    df['adj'] = adj
    df['prep'] = prep
    df['noun'] = noun
    
    return df

# %%
all_descrip = pd.concat([descrip_, descrip_a, descrip_b], ignore_index=True)

# %%
df = all_descrip.apply(analyze_description, axis = 1)
# Out:
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'right', u'VB')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'right', u'VB')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'animal', u'NN')
# (u'on', u'IN')
# (u'it', u'PRP')
# (u'Brown', u'NNP')
# (u'tarp', u'VBD')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'hotdog', u'VB')
# (u'vendor', u'NN')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'animal', u'JJ')
# (u'depiction', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'VBD')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'hotdog', u'VB')
# (u'vendor', u'NN')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'next', u'VB')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'tree', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'animal', u'JJ')
# (u'depiction', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'road', u'NN')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'right', u'VB')
# (u'next', u'JJ')
# (u'to', u'TO')
# (u'a', u'DT')
# (u'tree', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'Black', u'NNP')
# (u'trash', u'NN')
# (u'can', u'MD')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'right', u'JJ')
# (u'closest', u'JJS')
# (u'driveway', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'sidewalk', u'NN')
# (u'adjacent', u'JJ')
# (u'to', u'TO')
# (u'parked', u'VB')
# (u'silver', u'JJ')
# (u'truck', u'NN')
# (u'Please', u'NNP')
# (u'turn', u'VB')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'You', u'PRP')
# (u'will', u'MD')
# (u'see', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'right', u'RB')
# (u'away', u'RB')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'near', u'IN')
# (u'yellow', u'JJ')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'Black', u'NNP')
# (u'roller', u'NN')
# (u'trash', u'NN')
# (u'cab', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'walk', u'NN')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'SUV', u'NNP')
# (u'parked', u'VBD')
# (u'in', u'IN')
# (u'it', u'PRP')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'silver', u'NN')
# (u'trucked', u'VBN')
# (u'parked', u'VBN')
# (u'out', u'RP')
# (u'front', u'NN')
# (u'You', u'PRP')
# (u'may', u'MD')
# (u'have', u'VB')
# (u'to', u'TO')
# (u'move', u'VB')
# (u'the', u'DT')
# (u'camera', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'opposite', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'original', u'JJ')
# (u'view', u'NN')
# (u'Please', u'NNP')
# (u'turn', u'VB')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'You', u'PRP')
# (u'will', u'MD')
# (u'see', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'right', u'RB')
# (u'away', u'RB')
# (u'Brown', u'NNP')
# (u'tarp', u'NN')
# (u'wrapped', u'VBD')
# (u'on', u'IN')
# (u'object', u'NN')
# (u'under', u'IN')
# (u'yellow', u'NN')
# (u'and', u'CC')
# (u'red', u'JJ')
# (u'umbrella', u'NN')
# (u'left', u'VBD')
# (u'on', u'IN')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'street', u'NN')
# (u'when', u'WRB')
# (u'facing', u'VBG')
# (u'Monster', u'NNP')
# (u'billboard', u'NN')
# (u'Black', u'NNP')
# (u'roller', u'NN')
# (u'trash', u'NN')
# (u'cab', u'NN')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'side', u'NN')
# (u'walk', u'NN')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'end', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'SUV', u'NNP')
# (u'parked', u'VBD')
# (u'in', u'IN')
# (u'it', u'PRP')
# (u'at', u'IN')
# (u'the', u'DT')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'a', u'DT')
# (u'silver', u'NN')
# (u'trucked', u'VBN')
# (u'parked', u'VBN')
# (u'out', u'RP')
# (u'front', u'NN')
# (u'You', u'PRP')
# (u'may', u'MD')
# (u'have', u'VB')
# (u'to', u'TO')
# (u'move', u'VB')
# (u'the', u'DT')
# (u'camera', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'opposite', u'JJ')
# (u'side', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'from', u'IN')
# (u'the', u'DT')
# (u'original', u'JJ')
# (u'view.\xca', u'NN')
# (u'Please', u'NNP')
# (u'turn', u'VB')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'view', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'left', u'NN')
# (u'You', u'PRP')
# (u'will', u'MD')
# (u'see', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'right', u'RB')
# (u'away', u'RB')
# (u'Find', u'IN')
# (u'a', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'bench', u'NN')
# (u'A', u'DT')
# (u'row', u'NN')
# (u'of', u'IN')
# (u'umbrellas', u'JJ')
# (u'line', u'NN')
# (u'the', u'DT')
# (u'edge', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'along', u'IN')
# (u'with', u'IN')
# (u'chairs', u'NNS')
# (u'and', u'CC')
# (u'what', u'WP')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'vendor', u'JJ')
# (u'booths', u'NNS')
# (u'Midway', u'NNP')
# (u'down', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'visible', u'JJ')
# (u'and', u'CC')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'securing', u'VBG')
# (u'property', u'NN')
# (u'or', u'CC')
# (u'merchandise', u'NN')
# (u'while', u'IN')
# (u'a', u'DT')
# (u'man', u'NN')
# (u'sits', u'VBZ')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'chair', u'NN')
# (u'with', u'IN')
# (u'his', u'PRP$')
# (u'back', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'bungle', u'NN')
# (u'secured', u'VBN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'The', u'DT')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'on', u'IN')
# (u'a', u'DT')
# (u'brick', u'NN')
# (u'patio', u'NN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'with', u'IN')
# (u'the', u'DT')
# (u'tan', u'NN')
# (u'roof', u'NN')
# (u'that', u'WDT')
# (u'has', u'VBZ')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NNP')
# (u'parked', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'Find', u'IN')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')
# (u'A', u'DT')
# (u'row', u'NN')
# (u'of', u'IN')
# (u'umbrellas', u'JJ')
# (u'line', u'NN')
# (u'the', u'DT')
# (u'edge', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'along', u'IN')
# (u'with', u'IN')
# (u'chairs', u'NNS')
# (u'and', u'CC')
# (u'what', u'WP')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'vendor', u'JJ')
# (u'booths', u'NNS')
# (u'Midway', u'NNP')
# (u'down', u'IN')
# (u'the', u'DT')
# (u'street', u'NN')
# (u'a', u'DT')
# (u'large', u'JJ')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'is', u'VBZ')
# (u'visible', u'JJ')
# (u'and', u'CC')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'be', u'VB')
# (u'securing', u'VBG')
# (u'property', u'NN')
# (u'or', u'CC')
# (u'merchandise', u'NN')
# (u'while', u'IN')
# (u'a', u'DT')
# (u'man', u'NN')
# (u'sits', u'VBZ')
# (u'in', u'IN')
# (u'a', u'DT')
# (u'chair', u'NN')
# (u'with', u'IN')
# (u'his', u'PRP$')
# (u'back', u'NN')
# (u'to', u'TO')
# (u'the', u'DT')
# (u'bungle', u'NN')
# (u'secured', u'VBN')
# (u'by', u'IN')
# (u'the', u'DT')
# (u'brown', u'JJ')
# (u'tarp', u'NN')
# (u'The', u'DT')
# (u'bench', u'NN')
# (u'is', u'VBZ')
# (u'located', u'VBN')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'white', u'JJ')
# (u'house', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'bricks', u'NNS')
# (u'on', u'IN')
# (u'the', u'DT')
# (u'patio', u'NN')
# (u'There', u'EX')
# (u'is', u'VBZ')
# (u'a', u'DT')
# (u'white', u'JJ')
# (u'SUV', u'NN')
# (u'in', u'IN')
# (u'the', u'DT')
# (u'driveway', u'NN')
# (u'The', u'DT')
# (u'house', u'NN')
# (u'appears', u'VBZ')
# (u'to', u'TO')
# (u'have', u'VB')
# (u'a', u'DT')
# (u'second', u'JJ')
# (u'story', u'NN')
# (u'or', u'CC')
# (u'attic', u'JJ')
# (u'and', u'CC')
# (u'a', u'DT')
# (u'tan', u'JJ')
# (u'roof', u'NN')
# (u'There', u'EX')
# (u'are', u'VBP')
# (u'columns', u'NNS')
# (u'in', u'IN')
# (u'front', u'NN')
# (u'of', u'IN')
# (u'the', u'DT')
# (u'front', u'JJ')
# (u'door', u'NN')
# (u'Turn', u'NN')
# (u'to', u'TO')
# (u'find', u'VB')
# (u'the', u'DT')
# (u'yellow', u'JJ')
# (u'sign', u'NN')

# %%
df.to_csv('descriptions_syntax.csv')

# %%
def nameToIndex(name):
    if name == 'fiveMT':
        return 0
    if name == 'sevenMT':
        return 2
    if name == 'tenMT':
        return 1

# %%
df['exp_index'] = df.exp.apply(nameToIndex)
df2['exp_index'] = df2.exp.apply(nameToIndex)

# %%
df
# Out:
#     id  gen  trial        lat        lng  \
# 0    1    0      0  40.760051 -73.984679
# 1    2    0      1  40.766763 -73.666573
# 2    3    0      2 -16.736296 -69.713405
# 3    4    1      0  40.760051 -73.984679
# 4    5    1      1  40.766763 -73.666573
# 5    6    1      2 -16.736296 -69.713405
# 6    7    2      0  40.760051 -73.984679
# 7    8    2      1  40.766763 -73.666573
# 8    9    2      2 -16.736296 -69.713405
# 9   10    3      0  40.760051 -73.984679
# 10  11    3      1  40.719391 -73.509400
# 11  12    3      2 -16.736296 -69.713405
# 12   1    0      0  40.760051 -73.984679
# 13   2    0      1  40.766763 -73.666573
# 14   3    0      2 -16.736296 -69.713405
# 15   4    1      0  40.760051 -73.984679
# 16   5    1      1  40.766763 -73.666573
# 17   6    1      2 -16.736296 -69.713405
# 18   7    2      0  40.760051 -73.984679
# 19   8    2      1  40.766763 -73.666573
# 20   9    2      2 -16.736296 -69.713405
# 21   7    3      0  40.760051 -73.984679
# 22   8    3      1  40.766763 -73.666573
# 23   9    3      2 -16.736296 -69.713405
# 24   1    0      0  40.760051 -73.984679
# 25   3    0      2 -16.736296 -69.713405
# 26   2    0      1  40.719391 -73.509400
# 27   4    1      0  40.760051 -73.984679
# 28   5    1      1  40.719391 -73.509400
# 29   6    1      2 -16.736296 -69.713405
# 30   7    2      0  40.760051 -73.984679
# 31   8    2      1  40.719391 -73.509400
# 32   9    2      2 -16.736296 -69.713405
#
#                                           description      exp  adj  prep  \
# 0                                  Find a brown tarp.   fiveMT    1     1
# 1            Find the trash can right next to a tree.   fiveMT    1     1
# 2                               Find the yellow sign.   fiveMT    1     1
# 3                                  Find a brown tarp.   fiveMT    1     1
# 4            Find the trash can right next to a tree.   fiveMT    1     1
# 5        Find the yellow sign with the animal on it.    fiveMT    1     3
# 6                   Brown tarp next to hotdog vendor.   fiveMT    1     0
# 7   find the trash can next to the tree on the rig...   fiveMT    1     2
# 8   Find the yellow sign with the animal depiction...   fiveMT    3     4
# 9                   Brown tarp next to hotdog vendor.   fiveMT    1     0
# 10  find the trash can next to the tree on the rig...   fiveMT    1     2
# 11  Find the yellow sign with the animal depiction...   fiveMT    3     4
# 12                                 Find a brown tarp.    tenMT    1     1
# 13           Find the trash can right next to a tree.    tenMT    1     1
# 14                              Find the yellow sign.    tenMT    1     1
# 15  Brown tarp wrapped on object near yellow and r...    tenMT    2     4
# 16  Black trash can at the end of the right closes...    tenMT    4     3
# 17  Please turn the street view to the left. You w...    tenMT    1     0
# 18  Brown tarp wrapped on object near yellow and r...    tenMT    2     4
# 19  Black roller trash cab on the side walk at the...    tenMT    2     9
# 20  Please turn the street view to the left. You w...    tenMT    1     0
# 21  Brown tarp wrapped on object under yellow and ...    tenMT    1     4
# 22  Black roller trash cab on the side walk at the...    tenMT    2     9
# 23  Please turn the street view to the left. You w...    tenMT    1     0
# 24                                 Find a brown tarp.  sevenMT    1     1
# 25                              Find the yellow sign.  sevenMT    1     1
# 26                                    Find the bench.  sevenMT    0     1
# 27  A row of umbrellas line the edge of the street...  sevenMT    6     9
# 28  The bench is on a brick patio in front of the ...  sevenMT    2     5
# 29                              Find the yellow sign.  sevenMT    1     1
# 30  A row of umbrellas line the edge of the street...  sevenMT    6     9
# 31  The bench is located in front of the white hou...  sevenMT    6     6
# 32                      Turn to find the yellow sign.  sevenMT    1     0
#
#     noun  exp_index
# 0      1          0
# 1      2          0
# 2      1          0
# 3      1          0
# 4      2          0
# 5      2          0
# 6      2          0
# 7      4          0
# 8      4          0
# 9      2          0
# 10     4          0
# 11     4          0
# 12     1          1
# 13     2          1
# 14     1          1
# 15     8          1
# 16     6          1
# 17     5          1
# 18     8          1
# 19    15          1
# 20     5          1
# 21     9          1
# 22    15          1
# 23     5          1
# 24     1          2
# 25     1          2
# 26     1          2
# 27    16          2
# 28    10          2
# 29     1          2
# 30    16          2
# 31    13          2
# 32     2          2

# %%
f, axs = plt.subplots(3,3, figsize=(15,15))
'''
ax = f.add_subplot(111)
# Turn off axis lines and ticks of the big subplot
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')

# Set common labels
ax.set_xlabel('common xlabel')
ax.set_ylabel('common ylabel')
'''

for i, row in enumerate(axs):
    for j, ax in enumerate(row):
        ax.plot(df[(df.trial == i)&(df.exp_index == j)].gen,
                   df[(df.trial == i)&(df.exp_index == j)].adj, lw=1, marker='o')
        ax.plot(df[(df.trial == i)&(df.exp_index == j)].gen,
                   df[(df.trial == i)&(df.exp_index == j)].prep, lw=1, marker='o')
        ax.plot(df[(df.trial == i)&(df.exp_index == j)].gen,
                   df[(df.trial == i)&(df.exp_index == j)].noun, lw=1, marker='o')
        ax.set_xlim([-.5,3.5])
        ax.set_xticks(range(0,4))
        ax.set_ylim([0,18])
        ax.set_yticks(range(0,20,4))
        #ax.set_xlabel('Cycle')
        #ax.set_ylabel('Word count')
        
f.text(0.5, 0.04, 'Cycle', ha='center', size=18)

f.text(0.23, 0.9, 'Urban', ha='center', size=12)
f.text(0.5, 0.9, 'Suburban', ha='center', size=12)
f.text(0.77, 0.9, 'Rural', ha='center', size=12)

f.text(0.04, 0.5, 'Word count', va='center', rotation='vertical', size=18)

f.text(0.04, 0.23, 'Urban', ha='center', size=12)
f.text(0.04, 0.5, 'Suburban', ha='center', size=12)
f.text(0.04, 0.77, 'Rural', ha='center', size=12)

f.show()

# %%
f, axs = plt.subplots(3,3, figsize=(10,10))
for i, row in enumerate(axs):
    for j, ax in enumerate(row):
        ax.scatter(df2[(df2.trial == i)&(df2.exp_index == j)].gen,
                   df2[(df2.trial == i)&(df2.exp_index == j)].adj)
        ax.scatter(df2[(df2.trial == i)&(df2.exp_index == j)].gen,
                   df2[(df2.trial == i)&(df2.exp_index == j)].prep)
        ax.scatter(df2[(df2.trial == i)&(df2.exp_index == j)].gen,
                   df2[(df2.trial == i)&(df2.exp_index == j)].noun)
